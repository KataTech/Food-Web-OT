# %%
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
import pandas as pd 
import networkx as nx 
import pickle, os, sys

from src.model.graph import GraphOT_Factory

sns.set()

# %%
# Load food web data
with open("data/processed/foodweb_loc2nxgraph.pkl", "rb") as f: 
    food_webs = pickle.load(f)

# %%
food_webs_factory = GraphOT_Factory(food_webs)

# %%
food_webs_factory.save("data/processed/foodweb_factory.pkl")

# %%
cost_mat = food_webs_factory.ot_factory['Aberdare'].get_cost()
cost_mat[cost_mat == np.inf] = 10
plt.imshow(cost_mat)
plt.colorbar()

# %%
food_webs_factory = GraphOT_Factory.load("data/processed/foodweb_factory.pkl")
info = food_webs_factory.summary(save=True, save_path="scratch", save_title="food_web_summary")
# Out:
# --------------- Summary ---------------
# Total number of graphs       : 170.0
# Average number of nodes      : 51.7
# Average number of edges      : 170.76470588235293
# Largest food web             : Volcans  with 80 animals
# Smallest food web            : Banc dArguin with 8 animals
# Number of graphs with cycles : 147
