# %%
import pickle
import networkx as nx
import matplotlib.pyplot as plt
from src.model.util import vis_transport

# %%
with open("food_web_atom.pkl", "rb") as f: 
    atom_map = pickle.load(f)

atom_size, atom = atom_map[0]
vis_transport(atom, f"Food Web Atom {0}", percent=False)

# %%
atom[atom > 0.5] = 1
atom[atom <=0.5] = 0
graph = nx.DiGraph(atom)
nx.draw_networkx(graph)

# %%
atom_size, atom = atom_map[7]
vis_transport(atom, f"Food Web Atom {7}", percent=False)

# %%
atom[atom > 0.5] = 1
atom[atom <=0.5] = 0
graph = nx.DiGraph(atom)
nx.draw_networkx(graph)

# %%
atom_size, atom = atom_map[22]
vis_transport(atom, f"Food Web Atom {22}", percent=False)

# %%
atom[atom > 0.5] = 1
atom[atom <=0.5] = 0
graph = nx.DiGraph(atom)
nx.draw_networkx(graph)
